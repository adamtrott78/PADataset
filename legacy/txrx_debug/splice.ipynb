% %%
root = "/home/atrott/adamArchives/Adam/varMax/PADataset";
addpath(fullfile(root,"core"));
which pa_root
% Out:
% Error connecting to MATLAB. Check the status of MATLAB by clicking the "Open MATLAB" button. Retry after ensuring MATLAB is running successfully.

% %%
pa_setup_paths
% Out:
% PADataset MATLAB paths initialized.
% Repo root: /home/atrott/adamArchives/Adam/varMax/PADataset

% %%
rx_resplice_tape_simple("zigbee", "high_run01", 2, 'seed_k', 1600000, 'fallback_k', [6838931, 7488000], 'search_radius', 500, 'seed_radius', 10000, 'fallback_radius', 500, 'slip_frames', -1:1, 'make_png', false);

% %%
pa_root()
pa_protocol_roots("wifi")

% %%
seek
% Out:
% shard_id = 2
% Loaded OTA shard metadata:
%   /home/atrott/adamArchives/Adam/varMax/PADataset/txrx/tapes/ota/wifi/wifi_high_run01/ota_tape_shard_002.mat
% Samples: 1407000000 | Fs = 12.500000 MS/s
%
% Creating stacked figure 1/1 with 14 ranges...
%   Reading range 01: 1000001:1700000 ...
%   Computing spectrogram for range 01...
%   Reading range 02: 1700001:2400000 ...
%   Computing spectrogram for range 02...
%   Reading range 03: 2400001:3100000 ...
%   Computing spectrogram for range 03...
%   Reading range 04: 3100001:3800000 ...
%   Computing spectrogram for range 04...
%   Reading range 05: 3800001:4500000 ...
%   Computing spectrogram for range 05...
%   Reading range 06: 4500001:5200000 ...
%   Computing spectrogram for range 06...
%   Reading range 07: 5200001:5900000 ...
%   Computing spectrogram for range 07...
%   Reading range 08: 5900001:6600000 ...
%   Computing spectrogram for range 08...
%   Reading range 09: 6600001:7300000 ...
% ...
